# %%
import base64

with open("3.jpeg", "rb") as f:
    b64 = base64.b64encode(f.read()).decode("utf-8")
    print(b64)
# Out:
# ...

# %%
import base64

with open("5.png", "rb") as f:
    b64 = base64.b64encode(f.read()).decode("utf-8")
    print(b64)
# Out:
# ...
